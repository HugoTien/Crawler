# %%
# !pip install splinter
import splinter
import time
from splinter import Browser
import datetime
from datetime import datetime, timedelta, date
import os
import random

# %%
def august():
    
    browser = splinter.Browser(driver_name='chrome',executable_path='D:/chorme/chromedriver ')
    browser.driver.set_window_size(1680, 1050)
    for i in range(1,30):
        try:
            #設定去回程日期
            startdate = date.today() + timedelta(days=i) #起始日期
            backdate = startdate + timedelta(days=4)
            date1 = str(startdate) # 去程日期
            date2 = str(backdate)

            year1 = startdate.year 
            month1 = startdate.month
            day1 = startdate.day
            
            year2 = backdate.year
            month2 = backdate.month
            day2 = backdate.day
#             date1 = date1.split(" ")[0].replace("-","/")
#             year1 = date1.split("/")[0]
#             month1 = date1.split("/")[1]
#             day1 = date1.split("/")[2]


#             date2 = date2.split(" ")[0].replace("-","/")
#             year2 = date2.split("/")[0]
#             month2 = date2.split("/")[1]
#             day2 = date2.split("/")[2]        

            if str(month1) in ["9"]:
                break;


            browser.cookies.delete() # 刪除cookie
            browser.visit('http://www.flypeach.com/pc/tw') # 造訪網頁
            browser.click_link_by_id("trip_type_roundtrip") # 點選去回程
            time.sleep(random.randrange(3,5))

            browser.click_link_by_id("hyperlink-from") # 觸發選擇出發地點

            # 點選出發地
            element = browser.find_by_xpath('//div[@id="dialogFrom"]')[0]
            element1=element.find_by_xpath('//li[@id="TPE"]')[2]
            element1.click()
            time.sleep(random.randrange(3,5))

            # 點選回程地
            element2 = browser.find_by_xpath('//div[@id="dialogTo"]')
            time.sleep(1)
            element3=element2.find_by_xpath('//li[@id="KIX"]')[3]
            element3.click()
            time.sleep(random.randrange(3,5))

            # 點選去程日期
#             if day1 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day1 = day1.split("0")[1]
            aa = browser.find_by_css("div#dialogDepartingOn").find_by_css(".dayNormal").find_by_text(day1)[0]
            aa.click() # 點選

            time.sleep(random.randrange(3,5))


            # 點選回程日期
            if str(month2) in ["9"]: # 若回程日期為九月，按下個月
                nextmonthbutton = browser.find_by_css("div#dialogReturningOn").find_by_css(".monthForwardButton")
                nextmonthbutton.click()
                time.sleep(random.randrange(3,5))
#             if day2 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day2 = day2.split("0")[1]    
            bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text(day2)[1]
            bb.click() # 點選

            # 點選查詢
            time.sleep(3)
            cc = browser.find_by_name("flyinpeach-booking")
            cc.click()

            print(str(date1)+" Done")

            filename = date1.replace("/","_")
            with open('C:/Users/Java/Desktop/Project/Air_Crawler/樂桃html/{}.html'.format(filename),'w',encoding="utf-8") as f:
                f.write(browser.html)
            time.sleep(random.randrange(5,10))
        except:
            pass
        

    
# element1=element.find_by_xpath('//li[@id="TPE"]')[0]

# element1.click()

# find_by_xpath('//*[@id="dialogFrom"]/div[3]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]/div[1]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]/ul[1]').find_by_xpath('//*[@id="TPE"]').find_by_xpath('//*[@id="TPE"]/a').click()

                
# browser.click_link_by_id("TPE")
# $("#hyperlink-from").click(function(evt)
# browser.find_by_xpath('//*[@id="TPE"]').click()
        
#         browser.click_link_by_id("hyperlink-from")
#         button = browser.find_by_text('台北, 臺灣桃園國際機場 (TPE) ')
#         button[2].click
#         time.sleep(1)

    
#         time.sleep(1)

#         button = browser.find_by_css('.for-radio')[0].click()
#         time.sleep(1)
#         browser.find_by_text('台北（桃園）').first.click()
#         time.sleep(1)
#         time.sleep(1)
#         browser.find_by_text('大阪（關西）')[1].click()
#         time.sleep(3)

#         date = str(datetime.today() + timedelta(days=i))
#         date = date.split(" ")[0].replace("-","/")

#         browser.fill('travelDate1[date]', date)
#         time.sleep(2)
#         browser.fill('travelDate2[date]', date)
#         browser.find_by_xpath('//*[@id="adultPeopleBox"]').click() # 隨便點個東西
#         time.sleep(2)
#         browser.find_by_id("edit-submit-ticket").first.click()
#         time.sleep(5)


#         filename = date.replace("/","_")

#         print(str(date)+" Done")
#         with open('C:/Users/Java/Desktop/Project/Air_Crawler/html/{}.html'.format(filename),'w',encoding="utf-8") as f:
#             f.write(browser.html)
#         time.sleep(random.randrange(5,10))
#     except:
#         pass

# %%
def september():
    
    browser = splinter.Browser(driver_name='chrome',executable_path='D:/chorme/chromedriver ')
    browser.driver.set_window_size(1680, 1050)
    for i in range(1,30):
        try:
            #設定去回程日期
            startdate = date(2017,9,1) + timedelta(days=i) #起始日期
            backdate = startdate + timedelta(days=4)
            date1 = str(startdate) # 去程日期
            date2 = str(backdate)

            year1 = startdate.year 
            month1 = startdate.month
            day1 = startdate.day
            
            year2 = backdate.year
            month2 = backdate.month
            day2 = backdate.day
#             date1 = date1.split(" ")[0].replace("-","/")
#             year1 = date1.split("/")[0]
#             month1 = date1.split("/")[1]
#             day1 = date1.split("/")[2]


#             date2 = date2.split(" ")[0].replace("-","/")
#             year2 = date2.split("/")[0]
#             month2 = date2.split("/")[1]
#             day2 = date2.split("/")[2]        

            if str(month1) in ["10"]:
                break;


            browser.cookies.delete() # 刪除cookie
            browser.visit('http://www.flypeach.com/pc/tw') # 造訪網頁
            browser.click_link_by_id("trip_type_roundtrip") # 點選去回程
            time.sleep(random.randrange(3,5))

            browser.click_link_by_id("hyperlink-from") # 觸發選擇出發地點

            # 點選出發地
            element = browser.find_by_xpath('//div[@id="dialogFrom"]')[0]
            element1=element.find_by_xpath('//li[@id="TPE"]')[2]
            element1.click()
            time.sleep(random.randrange(3,5))

            # 點選回程地
            element2 = browser.find_by_xpath('//div[@id="dialogTo"]')
            time.sleep(1)
            element3=element2.find_by_xpath('//li[@id="KIX"]')[3]
            element3.click()
            time.sleep(random.randrange(3,5))

            
#             if day1 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day1 = day1.split("0")[1]

             # 8月爬九月，按一下月份
            nextmonthbutton = browser.find_by_css("div#dialogDepartingOn").find_by_css(".monthForwardButton")
            nextmonthbutton.click()
            time.sleep(random.randrange(3,5))
            
            # 點選去程日期
            aa = browser.find_by_css("div#dialogDepartingOn").find_by_css(".dayNormal").find_by_text(day1)[0]
            aa.click() # 點選

            time.sleep(random.randrange(3,5))


            # 點選回程日期
            if str(month2) in ["10"]: # 若回程日期為九月，按下個月
                nextmonthbutton = browser.find_by_css("div#dialogReturningOn").find_by_css(".monthForwardButton")
                nextmonthbutton.click()
                time.sleep(random.randrange(3,5))
#             if day2 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day2 = day2.split("0")[1]    
            bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text(day2)[1]
            bb.click() # 點選

            # 點選查詢
            time.sleep(3)
            cc = browser.find_by_name("flyinpeach-booking")
            cc.click()

            print(str(date1)+" Done")

            filename = date1.replace("/","_")
            with open('C:/Users/Java/Desktop/Project/Air_Crawler/樂桃html/{}.html'.format(filename),'w',encoding="utf-8") as f:
                f.write(browser.html)
            time.sleep(random.randrange(5,10))
        except:
            pass
        

    
# element1=element.find_by_xpath('//li[@id="TPE"]')[0]

# element1.click()

# find_by_xpath('//*[@id="dialogFrom"]/div[3]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]/div[1]').find_by_xpath('//*[@id="dialogFrom"]/div[3]/div[1]/ul[1]').find_by_xpath('//*[@id="TPE"]').find_by_xpath('//*[@id="TPE"]/a').click()

                
# browser.click_link_by_id("TPE")
# $("#hyperlink-from").click(function(evt)
# browser.find_by_xpath('//*[@id="TPE"]').click()
        
#         browser.click_link_by_id("hyperlink-from")
#         button = browser.find_by_text('台北, 臺灣桃園國際機場 (TPE) ')
#         button[2].click
#         time.sleep(1)

    
#         time.sleep(1)

#         button = browser.find_by_css('.for-radio')[0].click()
#         time.sleep(1)
#         browser.find_by_text('台北（桃園）').first.click()
#         time.sleep(1)
#         time.sleep(1)
#         browser.find_by_text('大阪（關西）')[1].click()
#         time.sleep(3)

#         date = str(datetime.today() + timedelta(days=i))
#         date = date.split(" ")[0].replace("-","/")

#         browser.fill('travelDate1[date]', date)
#         time.sleep(2)
#         browser.fill('travelDate2[date]', date)
#         browser.find_by_xpath('//*[@id="adultPeopleBox"]').click() # 隨便點個東西
#         time.sleep(2)
#         browser.find_by_id("edit-submit-ticket").first.click()
#         time.sleep(5)


#         filename = date.replace("/","_")

#         print(str(date)+" Done")
#         with open('C:/Users/Java/Desktop/Project/Air_Crawler/html/{}.html'.format(filename),'w',encoding="utf-8") as f:
#             f.write(browser.html)
#         time.sleep(random.randrange(5,10))
#     except:
#         pass

# %%
august()
# Out:
# 2017-08-05 Done
# 2017-08-06 Done
# 2017-08-07 Done
# 2017-08-08 Done
# 2017-08-09 Done
# 2017-08-10 Done
# 2017-08-11 Done
# 2017-08-12 Done
# 2017-08-13 Done
# 2017-08-14 Done
# 2017-08-15 Done
# 2017-08-16 Done
# 2017-08-17 Done
# 2017-08-18 Done
# 2017-08-19 Done
# 2017-08-20 Done
# 2017-08-21 Done
# 2017-08-22 Done
# 2017-08-23 Done
# 2017-08-24 Done
# 2017-08-25 Done
# 2017-08-26 Done
# 2017-08-27 Done

# %%
september()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-b23de5255c5e> in <module>()
# ----> 1 september()
#
# <ipython-input-36-7e82fd767073> in september()
#       1 def september():
#       2
# ----> 3     browser = splinter.Browser(driver_name='chrome',executable_path='D:/chorme/chromedriver ')
#       4     browser.driver.set_window_size(1680, 1050)
#       5     for i in range(1,30):
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\browser.py in Browser(driver_name, *args, **kwargs)
#      61     except KeyError:
#      62         raise DriverNotFoundError("No driver for %s" % driver_name)
# ---> 63     return driver(*args, **kwargs)
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\driver\webdriver\chrome.py in __init__(self, options, user_agent, wait_time, fullscreen, incognito, **kwargs)
#      29             options.add_argument('--kiosk')
# ...

# %%
file = open('C:/Users/Java/Desktop/Project/Air_Crawler/樂桃html/2018_01_28.html','r',encoding="utf-8")  # 如果沒有第二個參數，表示預設的模式是 'r'
html = file.readlines()
print(html)
file.close()

# %%
date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a9564ebc3289> in <module>()
# ----> 1 date
#
# NameError: name 'date' is not defined

# %%
element2 = browser.find_by_xpath('//div[@id="dialogTo"]')
element2
element3=element2.find_by_xpath('//li[@id="KIX"]')
element3.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotVisibleException                Traceback (most recent call last)
# <ipython-input-70-8ff632aae786> in <module>()
#       2 element2
#       3 element3=element2.find_by_xpath('//li[@id="KIX"]')
# ----> 4 element3.click()
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     544
#     545     def click(self):
# --> 546         self._element.click()
#     547
#     548     def check(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      75     def click(self):
#      76         """Clicks the element."""
# ---> 77         self._execute(Command.CLICK_ELEMENT)
#      78
#      79     def submit(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     491             params = {}
# ...

# %%
august()

# %%
# http://www.victorgau.com/?p=4024
file = open('C:/Users/Java/Desktop/Project/Air_Crawler/html/2017_08_02.html'.format(filename),'r',encoding="utf-8")  # 如果沒有第二個參數，表示預設的模式是 'r'
html = file.readlines()
print(html)
file.close()
# Out:
# ['<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-hant" class=" htmlimports no-proximity flash transferables applicationcache blobconstructor blob-constructor cookies cors customprotocolhandler customevent dataview eventlistener geolocation history no-ie8compat json notification postmessage queryselector serviceworker templatestrings typedarrays websockets webaudio svg cssescape supports target no-microdata mutationobserver picture es5array es5date es5function es5object no-strictmode es5string no-es5syntax es5undefined no-es5 no-es6array generators es6math es6number es6object promises no-es6string devicemotion deviceorientation filereader beacon no-lowbandwidth eventsource fetch xhrresponsetype xhr2 speechsynthesis localstorage sessionstorage websqldatabase svgfilters urlparser websocketsbinary no-framed sharedworkers webworkers no-contains no-contextmenu cssall willchange classlist documentfragment svgasimg no-ambientlight hashchange inputsearchevent pointerevents
# ...

# %%
element2

# %%
for i in range(1,180):
        date = str(datetime.today() + timedelta(days=i))
        date = date.split(" ")[0].replace("-","/")
        print(date)
# Out:
# 2017/08/03
# 2017/08/04
# 2017/08/05
# 2017/08/06
# 2017/08/07
# 2017/08/08
# 2017/08/09
# 2017/08/10
# 2017/08/11
# 2017/08/12
# 2017/08/13
# 2017/08/14
# 2017/08/15
# 2017/08/16
# 2017/08/17
# 2017/08/18
# 2017/08/19
# 2017/08/20
# 2017/08/21
# 2017/08/22
# 2017/08/23
# 2017/08/24
# 2017/08/25
# 2017/08/26
# 2017/08/27
# 2017/08/28
# 2017/08/29
# 2017/08/30
# 2017/08/31
# 2017/09/01
# 2017/09/02
# 2017/09/03
# 2017/09/04
# 2017/09/05
# 2017/09/06
# 2017/09/07
# 2017/09/08
# 2017/09/09
# 2017/09/10
# 2017/09/11
# 2017/09/12
# 2017/09/13
# 2017/09/14
# 2017/09/15
# 2017/09/16
# 2017/09/17
# 2017/09/18
# 2017/09/19
# 2017/09/20
# 2017/09/21
# 2017/09/22
# 2017/09/23
# 2017/09/24
# 2017/09/25
# 2017/09/26
# 2017/09/27
# 2017/09/28
# 2017/09/29
# 2017/09/30
# 2017/10/01
# 2017/10/02
# 2017/10/03
# 2017/10/04
# 2017/10/05
# 2017/10/06
# 2017/10/07
# 2017/10/08
# 2017/10/09
# 2017/10/10
# 2017/10/11
# 2017/10/12
# 2017/10/13
# 2017/10/14
# 2017/10/15
# 2017/10/16
# 2017/10/17
# ...

# %%
year = date.split("/")[0]
month = date.split("/")[1]
day = date.split("/")[2]

print(year)
print(month)
print(day)
# Out:
# 2018
# 01
# 28

# %%
aa

# %%
bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text("5")
bb

# %%
if day in ["01","02","03","04","05",'06','07',"08","09"]:
    day = day.split("0")[1]

# %%
day
# Out:
# '1'

# %%
day = "01"

# %%
day1
# Out:
# '3'

# %%
aa = browser.find_by_css("div#dialogDepartingOn").find_by_css(".dayNormal").find_by_text(3)[0]
aa

# %%
aa.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-29-b05a89ce3111> in <module>()
# ----> 1 aa.click()
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     544
#     545     def click(self):
# --> 546         self._element.click()
#     547
#     548     def check(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      75     def click(self):
#      76         """Clicks the element."""
# ---> 77         self._execute(Command.CLICK_ELEMENT)
#      78
#      79     def submit(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     491             params = {}
#     492         params['id'] = self._id
# --> 493         return self._parent.execute(command, params)
#     494
# ...

# %%
bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text(day2)[1]
bb.click() # 點選
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      39         try:
# ---> 40             return super(ElementList, self).__getitem__(index)
#      41         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-30-7f774270e4fe> in <module>()
# ----> 1 bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text(day2)[1]
#       2 bb.click() # 點選
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      42             raise ElementDoesNotExist(
#      43                 u'no elements could be found with {0} "{1}"'.format(
# ...

# %%
day1
# Out:
# '03'

# %%
type(day1)
# Out:
# str

# %%
type(date)
# Out:
# datetime.datetime

# %%
time =datetime.date(time)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-aa4159767470> in <module>()
# ----> 1 time =datetime.date(time)
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'datetime.date'

# %%
time
# Out:
# datetime.date(2017, 9, 1)

# %%
a =date.today()

# %%
a.month
# Out:
# 8

# %%
month1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4d2a9bf1c3e2> in <module>()
# ----> 1 month1
#
# NameError: name 'month1' is not defined

# %%
a.day
# Out:
# 3

# %%
browser = splinter.Browser(driver_name='chrome',executable_path='D:/chorme/chromedriver ')
browser.driver.set_window_size(1680, 1050)
for i in range(1,30):

    #設定去回程日期
    startdate = date.today() + timedelta(days=i) #起始日期
    backdate = startdate + timedelta(days=5)
    date1 = str(startdate) # 去程日期
    date2 = str(backdate)

    year1 = startdate.year 
    month1 = startdate.month
    day1 = startdate.day

    year2 = backdate.year
    month2 = backdate.month
    day2 = backdate.day
#             date1 = date1.split(" ")[0].replace("-","/")
#             year1 = date1.split("/")[0]
#             month1 = date1.split("/")[1]
#             day1 = date1.split("/")[2]


#             date2 = date2.split(" ")[0].replace("-","/")
#             year2 = date2.split("/")[0]
#             month2 = date2.split("/")[1]
#             day2 = date2.split("/")[2]        

    if str(month1) in ["9"]:
        break;


    browser.cookies.delete() # 刪除cookie
    browser.visit('http://www.flypeach.com/pc/tw') # 造訪網頁
    browser.click_link_by_id("trip_type_roundtrip") # 點選去回程
    time.sleep(random.randrange(3,5))

    browser.click_link_by_id("hyperlink-from") # 觸發選擇出發地點

    # 點選出發地
    element = browser.find_by_xpath('//div[@id="dialogFrom"]')[0]
    element1=element.find_by_xpath('//li[@id="TPE"]')[2]
    element1.click()
    time.sleep(random.randrange(3,5))

    # 點選回程地
    element2 = browser.find_by_xpath('//div[@id="dialogTo"]')
    time.sleep(1)
    element3=element2.find_by_xpath('//li[@id="KIX"]')[3]
    element3.click()
    time.sleep(random.randrange(3,5))

    # 點選去程日期
#             if day1 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day1 = day1.split("0")[1]
#<div id="backgroundDialog" style="opacity: 0.7; display: block; height: 918px;"></div>
    hidearea = browser.find_by_id("")
    aa = browser.find_by_css("div#dialogDepartingOn").find_by_css(".dayNormal").find_by_text(day1)[0]
    aa.click() # 點選

    time.sleep(random.randrange(3,5))


    # 點選回程日期
    if str(month2) in ["9"]: # 若回程日期為九月，按下個月
        nextmonthbutton = browser.find_by_css("div#dialogReturningOn").find_by_css(".monthForwardButton")
        nextmonthbutton.click()
        time.sleep(random.randrange(3,5))
#             if day2 in ["01","02","03","04","05",'06','07',"08","09"]: #若日期為個位數，切掉0
#                 day2 = day2.split("0")[1]    
    bb = browser.find_by_css("div#dialogReturningOn").find_by_css(".dayNormal").find_by_text(day2)[1]
    bb.click() # 點選

    # 點選查詢
    time.sleep(3)
    cc = browser.find_by_name("flyinpeach-booking")
    cc.click()

    print(str(date1)+" Done")

    filename = date1.replace("/","_")
    with open('C:/Users/Java/Desktop/Project/Air_Crawler/樂桃html/{}.html'.format(filename),'w',encoding="utf-8") as f:
        f.write(browser.html)
    time.sleep(random.randrange(5,10))
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-30-7ce1a66ddd98> in <module>()
#      55 #                 day1 = day1.split("0")[1]
#      56     aa = browser.find_by_css("div#dialogDepartingOn").find_by_css(".dayNormal").find_by_text(day1)[0]
# ---> 57     aa.click() # 點選
#      58
#      59     time.sleep(random.randrange(3,5))
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     544
#     545     def click(self):
# --> 546         self._element.click()
#     547
#     548     def check(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      75     def click(self):
#      76         """Clicks the element."""
# ---> 77         self._execute(Command.CLICK_ELEMENT)
#      78
#      79     def submit(self):
#
# ...

# %%
hidearea = browser.find_by_id("backgroundDialog")

# %%
hidearea.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-33-ce6c5c514faa> in <module>()
# ----> 1 hidearea.click()
#
# C:\Users\Java\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     544
#     545     def click(self):
# --> 546         self._element.click()
#     547
#     548     def check(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      75     def click(self):
#      76         """Clicks the element."""
# ---> 77         self._execute(Command.CLICK_ELEMENT)
#      78
#      79     def submit(self):
#
# C:\Users\Java\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     491             params = {}
#     492         params['id'] = self._id
# --> 493         return self._parent.execute(command, params)
#     494
# ...
